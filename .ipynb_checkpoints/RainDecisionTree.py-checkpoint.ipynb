# %%
import pandas as pd
import numpy as np
from sklearn.tree import DecisionTreeClassifier, export_graphviz
from sklearn.model_selection import train_test_split

import os
print(os.listdir('./data'))
# Out:
# ['weather-dataset-rattle-package.zip', 'suicide-rates-overview-1985-to-2016.zip', 'weatherAUS.csv', 'master.csv']

# %%
df = pd.read_csv('./data/weatherAUS.csv')
df.head(5)
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1  2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2  2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3  2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4  2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Humidity3pm  Pressure9am  \
# 0           W           44.0          W  ...        22.0       1007.7
# 1         WNW           44.0        NNW  ...        25.0       1010.6
# 2         WSW           46.0          W  ...        30.0       1007.6
# 3          NE           24.0         SE  ...        16.0       1017.6
# 4           W           41.0        ENE  ...        33.0       1010.8
#
#    Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  RISK_MM  \
# ...

# %%
df = df.fillna(-1)
df.head(3)
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008-12-01   Albury     13.4     22.9       0.6         -1.0      -1.0
# 1  2008-12-02   Albury      7.4     25.1       0.0         -1.0      -1.0
# 2  2008-12-03   Albury     12.9     25.7       0.0         -1.0      -1.0
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Humidity3pm  Pressure9am  \
# 0           W           44.0          W  ...        22.0       1007.7
# 1         WNW           44.0        NNW  ...        25.0       1010.6
# 2         WSW           46.0          W  ...        30.0       1007.6
#
#    Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  RISK_MM  \
# 0       1007.1       8.0      -1.0     16.9     21.8         No      0.0
# 1       1007.8      -1.0      -1.0     17.2     24.3         No      0.0
# 2       1008.7      -1.0       2.0     21.0     23.2         No      0.0
#
#    RainTomorrow
# 0            No
# 1            No
# 2            No
#
# ...

# %%
df = df.drop(['Location', 'WindGustDir', 'WindGustSpeed', 'WindDir3pm', 'WindSpeed9am', 'WindSpeed3pm'], axis=1)
df.head()
# Out:
#          Date  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindDir9am  \
# 0  2008-12-01     13.4     22.9       0.6         -1.0      -1.0          W
# 1  2008-12-02      7.4     25.1       0.0         -1.0      -1.0        NNW
# 2  2008-12-03     12.9     25.7       0.0         -1.0      -1.0          W
# 3  2008-12-04      9.2     28.0       0.0         -1.0      -1.0         SE
# 4  2008-12-05     17.5     32.3       1.0         -1.0      -1.0        ENE
#
#    Humidity9am  Humidity3pm  Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  \
# 0         71.0         22.0       1007.7       1007.1       8.0      -1.0
# 1         44.0         25.0       1010.6       1007.8      -1.0      -1.0
# 2         38.0         30.0       1007.6       1008.7      -1.0       2.0
# 3         45.0         16.0       1017.6       1012.8      -1.0      -1.0
# 4         82.0         33.0       1010.8       1006.0       7.0       8.0
#
#    Temp9am  Temp3pm RainToday  RISK_MM RainTomorrow
# ...

# %%
X = pd.get_dummies(df.drop('RainTomorrow', axis=1))
Y = pd.get_dummies(df['RainTomorrow'])

X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
X_train.head(5)
# Out:
#         MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  Humidity9am  \
# 17969      15.1     23.9       0.0         -1.0      -1.0         38.0
# 124769      9.7     14.2       7.6         -1.0      -1.0         91.0
# 39287      13.2     25.4       0.0          3.2       8.8         79.0
# 127749      7.6     14.8       0.0          4.0       7.0         52.0
# 40651      12.9     22.2       0.0          4.0       7.9         69.0
#
#         Humidity3pm  Pressure9am  Pressure3pm  Cloud9am  ...  WindDir9am_SE  \
# 17969          68.0       1001.9       1002.4      -1.0  ...              0
# 124769         56.0       1008.2       1007.7      -1.0  ...              0
# 39287          63.0       1025.2       1021.5       6.0  ...              0
# 127749         45.0       1004.6       1001.4      -1.0  ...              0
# 40651          52.0       1023.0       1021.2       6.0  ...              0
#
#         WindDir9am_SSE  WindDir9am_SSW  WindDir9am_SW  WindDir9am_W  \
# ...

# %%
dtree = DecisionTreeClassifier(max_depth=5, min_samples_split=20)
dtree = dtree.fit(X_train, y_train)

# %%
from sklearn.metrics import accuracy_score

y_predict = dtree.predict(X_test)
accuracy_score(y_predict, y_test)
# Out:
# 1.0

# %%
from sklearn.externals.six import StringIO
import pydotplus

dot_data = StringIO()
export_graphviz(dtree, 
                out_file=dot_data,  
                filled=True, 
                feature_names=list(X_train),
                class_names=['Rain Tomorrow','Not Rain Tomorrow'],
                special_characters=True)
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())
graph.write_pdf('tree.pdf')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-66-69712029d1c9> in <module>
#       9                 #class_names=['Rain Tomorrow','Not Rain Tomorrow'],
#      10                 special_characters=True)
# ---> 11 graph = pydotplus.graph_from_dot_data(dot_data.getvalue())
#      12 graph.write_pdf('tree.pdf')
#
# AttributeError: 'str' object has no attribute 'getvalue'
